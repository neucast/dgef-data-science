# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from scipy.stats import t as tstudent
import scipy.stats as ss
import matplotlib.pyplot as plt
from datetime import datetime, date
from pandas.plotting import scatter_matrix
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#Simulación de una normal bivariada con correlación rho = -0.8
rho = -0.9
n = 1000
vx = np.random.multivariate_normal([0,0],[[1,rho],[rho,1]],n)
x, y = [], []
for i in range(n):
    x.extend([vx[i][0]])
    y.extend([vx[i][1]])
#Gráfica
fig = plt.figure(figsize=(5., 5.))
ax = fig.add_subplot(1,1,1)
plt.scatter(x,y,color="green")
plt.show()

# %%
#Simulación de una normal bivariada con correlación rho = 0.9
rho = 0.9
n = 1000
vx = np.random.multivariate_normal([0,0],[[1,rho],[rho,1]],n)
x, y = [], []
for i in range(n):
    x.extend([vx[i][0]])
    y.extend([vx[i][1]])
#Gráfica
fig = plt.figure(figsize=(5., 5.))
ax = fig.add_subplot(1,1,1)
plt.scatter(x,y,color="red")
plt.show()

# %%
#Simulación de una normal bivariada con correlación rho = 0
rho = 0.
n = 1000
vx = np.random.multivariate_normal([0,0],[[1,rho],[rho,1]],n)
x, y = [], []
for i in range(n):
    x.extend([vx[i][0]])
    y.extend([vx[i][1]])
#Gráfica
fig = plt.figure(figsize=(5., 5.))
ax = fig.add_subplot(1,1,1)
plt.scatter(x,y,color="darkblue")
plt.show()
